# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ###### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * Work with Jupyter Notebook;
# * Understand Markdowns;
# * Evaluate Data Science Tool Knowledge;
# * Work with python kernel.

# %% [markdown]
# ##### Five of the most popular languages that Data Scientists use are:
# ###### 1. **Python**;
# ###### 2. **R**;
# ###### 3. **SQL**;
# ###### 4. **Scalla**;
# ###### 5. **Java**.

# %% [markdown]
# ##### Some of the commonly used libraries used by Data Scientists include:
# ###### + **Pandas** *(To help in Scientifics Computing)*
# ###### + **Matplotlib** *(To help in Visualization)*
# ###### + **Keras** *(To Machine Learning)*
# ###### + **TensorFlow** *(To Deep Learning)*

# %% [markdown]
# | Data Science Tools |
# | - |
# | RStudio |
# | Github |
# | Python |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers.

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60.

# %%
def mintoh(min):
    return(min/60)
print(mintoh(200))
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# David Bernardo Alvarenga Vieira
